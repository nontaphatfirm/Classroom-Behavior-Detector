# %%
# !python --version
# Out:
# Python 3.10.13

# %%
#git clone yolov10
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20286, done.
# remote: Counting objects: 100% (365/365), done.
# remote: Compressing objects: 100% (174/174), done.
# remote: Total 20286 (delta 242), reused 290 (delta 191), pack-reused 19921
# Receiving objects: 100% (20286/20286), 11.36 MiB | 23.65 MiB/s, done.
# Resolving deltas: 100% (14221/14221), done.

# %%
cd yolov10
# Out:
# [Errno 2] No such file or directory: 'yolov10'
# /kaggle/working/yolov10

# %%
# !pip install .
# Out:
# Processing /kaggle/working/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.10.0.82)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.32.3)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.66.4)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.1.34)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.2.1)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.12.1)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2024.3.1)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.1.34) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (2.1.3)
# Requirement already satisfied: mpmath<1.4.0,>=1.1.0 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.34) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=731144 sha256=97948e9cc97c49cef3a54ea6010995e6a73f049f28e130c3e62a11b88abfade5
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vkjmjidd/wheels/42/8a/a9/9cce36b0b3d4ada7292a5a495abef6993ad1db52a921496752
# Successfully built ultralytics
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.34

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /kaggle/working/yolov10/weights/yolov10n.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10s.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10m.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10b.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10x.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10l.pt

# %%
# !pip install wandb --upgrade
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.17.0)
# Collecting wandb
#   Downloading wandb-0.17.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (3.11.0)
# Requirement already satisfied: protobuf!=4.21.0,<6,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.32.3)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.3.1)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Downloading wandb-0.17.1-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.8/6.8 MB 22.1 MB/s eta 0:00:0000:0100:01
# Installing collected packages: wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.17.0
#     Uninstalling wandb-0.17.0:
#       Successfully uninstalled wandb-0.17.0
# Successfully installed wandb-0.17.1

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
#train model
# !yolo task=detect mode=train epochs=100 batch=8 plots=True model=weights/yolov10x.pt data=/kaggle/input/detecting-student-classroom-behavior2/kaggle_config_fold3.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.28 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# engine/trainer: task=detect, mode=train, model=weights/yolov10x.pt, data=/kaggle/input/detecting-student-classroom-behavior2/kaggle_config_fold3.yaml, epochs=100, time=None, patience=100, batch=8, imgsz=640, save=True, save_period=-1, val_period=1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/yolov10/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 13.9MB/s]
# 2024-06-07 11:21:59.712290: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-06-07 11:21:59.712439: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-06-07 11:21:59.995777: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1    213120  ultralytics.nn.modules.block.SCDown          [320, 640, 3, 2]
#   6                  -1  6   4604160  ultralytics.nn.modules.block.C2fCIB          [640, 640, 6, True]
#   7                  -1  1    417920  ultralytics.nn.modules.block.SCDown          [640, 640, 3, 2]
#   8                  -1  3   2712960  ultralytics.nn.modules.block.C2fCIB          [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1   1545920  ultralytics.nn.modules.block.PSA             [640, 640]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   3122560  ultralytics.nn.modules.block.C2fCIB          [1280, 640, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  17                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2917760  ultralytics.nn.modules.block.C2fCIB          [960, 640, 3, True]
#  20                  -1  1    417920  ultralytics.nn.modules.block.SCDown          [640, 640, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   3122560  ultralytics.nn.modules.block.C2fCIB          [1280, 640, 3, True]
#  23        [16, 19, 22]  1   4390818  ultralytics.nn.modules.head.v10Detect        [3, [320, 640, 640]]
# YOLOv10x summary: 688 layers, 31660658 parameters, 31660642 gradients, 171.0 GFLOPs
#
# Transferred 1123/1135 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# wandb: Currently logged in as: nontaphatfirm (nontaphat). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.1
# wandb: Run data is saved locally in /kaggle/working/yolov10/wandb/run-20240607_112217-0dpoqjyq
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train
# wandb: ⭐️ View project at https://wandb.ai/nontaphat/YOLOv8
# wandb: 🚀 View run at https://wandb.ai/nontaphat/YOLOv8/runs/0dpoqjyq
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|██████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 71.4MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/input/detecting-student-classroom-behavior2/data_test2/d
# train: WARNING ⚠️ /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/images/train_fold_3/1276033.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1459]
# train: WARNING ⚠️ Cache directory /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/labels is not writeable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
# val: Scanning /kaggle/input/detecting-student-classroom-behavior2/data_test2/dat
# val: WARNING ⚠️ Cache directory /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/labels is not writeable, cache not saved.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 185 weight(decay=0.0), 198 weight(decay=0.0005), 197 bias(decay=0.0)
# TensorBoard: model graph visualization added ✅
# Image sizes 640 train, 640 val
# Using 2 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       1/100      10.5G      1.319      1.992      1.507      1.346      2.315
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.319      0.428      0.274      0.133
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       2/100      10.8G      1.476      2.016      1.634       1.54      2.196
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.289      0.388      0.237      0.125
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       3/100      10.8G      1.442      1.927      1.603      1.502        2.1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.334      0.453      0.306      0.173
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       4/100      10.8G      1.341      1.797      1.536      1.407      1.967
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.366      0.496       0.35      0.198
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       5/100      10.8G      1.306      1.715      1.519      1.368      1.888
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.388      0.533      0.412      0.255
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       6/100      10.8G      1.237      1.603      1.465      1.311      1.756
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.467      0.537      0.465      0.298
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       7/100      10.8G      1.174      1.549      1.425      1.254      1.684
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.457      0.593       0.45      0.295
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       8/100      10.8G      1.145      1.505      1.403      1.219       1.65
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.478      0.586      0.486      0.324
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       9/100      10.8G      1.121      1.447      1.387      1.199      1.578
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.482      0.588      0.507      0.347
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      10/100      10.8G      1.098      1.426      1.366      1.178      1.561
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.477      0.564      0.524      0.359
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      11/100      10.8G      1.074      1.386      1.354      1.154      1.515
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.545       0.59      0.564      0.388
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      12/100      10.8G      1.044      1.316      1.329      1.139      1.428
# IOPub message rate exceeded.
# The notebook server will temporarily stop sending output
# to the client in order to avoid crashing it.
# To change this limit, set the config variable
# `--NotebookApp.iopub_msg_rate_limit`.
#
# Current values:
# NotebookApp.iopub_msg_rate_limit=1000.0 (msgs/sec)
# NotebookApp.rate_limit_window=3.0 (secs)
#      25/100      10.8G     0.8721      1.063      1.208     0.9541      1.152
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.674      0.636      0.693      0.508
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      26/100      10.8G      0.861      1.023      1.201     0.9419      1.111
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.637      0.672       0.68      0.503
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      27/100      10.8G     0.8536      1.032      1.192     0.9382      1.124
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.632       0.67       0.69      0.512
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      28/100      10.8G     0.8364     0.9763      1.174     0.9196       1.06
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.644      0.682      0.706      0.519
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      29/100      10.8G     0.8397     0.9821      1.187     0.9198      1.066
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.651      0.657      0.697      0.516
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      30/100      10.8G     0.8283      0.968      1.173     0.9079      1.049
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.646      0.703      0.717      0.535
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      31/100      10.8G     0.8281     0.9625      1.172     0.9074      1.053
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.679      0.683      0.725      0.541
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      32/100      10.9G     0.8138     0.9342      1.162     0.8889      1.023
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.675      0.682      0.721      0.535
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      33/100      10.8G     0.8062     0.9224      1.156     0.8834      1.005
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.689      0.667      0.718      0.541
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      34/100      10.8G     0.8016     0.9149      1.152     0.8832     0.9979
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.697      0.689      0.734      0.551
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      35/100      10.8G     0.7988     0.9024      1.152     0.8743     0.9841
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.686      0.686      0.735      0.552
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      36/100      10.8G     0.7835     0.8911      1.144     0.8611     0.9727
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.687      0.689      0.728      0.545
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      37/100      10.8G     0.7861     0.8789      1.142     0.8641     0.9573
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.671      0.688      0.731      0.553
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      38/100      10.8G     0.7793     0.8671      1.139     0.8568     0.9468
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.708        0.7      0.743      0.558
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      39/100      10.8G     0.7701     0.8637      1.132     0.8443      0.942
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.686      0.699      0.732       0.55
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      40/100      10.8G     0.7696     0.8422      1.129     0.8463     0.9251
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.707      0.693      0.748      0.569
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      41/100      10.8G      0.756     0.8227      1.117     0.8317     0.8973
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.681      0.723      0.747      0.568
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      42/100      10.8G     0.7446     0.8081      1.113     0.8195     0.8801
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.681      0.695      0.738      0.559
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      43/100      10.8G     0.7571     0.8034       1.12     0.8343     0.8765
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.698      0.698      0.742      0.558
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      44/100      10.8G     0.7349     0.7988      1.112       0.81     0.8771
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.717      0.684      0.745      0.567
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      45/100      10.8G     0.7339     0.7818      1.106     0.8064     0.8533
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.691      0.717      0.746      0.566
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      46/100      10.8G     0.7348     0.7831      1.107     0.8014     0.8612
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.715      0.689      0.742      0.563
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      47/100      10.8G       0.72     0.7588      1.093     0.7939     0.8315
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.683      0.716      0.736      0.563
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      48/100      10.8G     0.7148     0.7409      1.093     0.7844     0.8091
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109       0.69      0.721      0.751      0.574
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      49/100      10.8G     0.7064     0.7429       1.09     0.7786     0.8128
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.701       0.71      0.743      0.566
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      50/100      10.8G     0.7038     0.7327      1.084     0.7764      0.804
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.716        0.7      0.755      0.576
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      51/100      10.8G     0.7038     0.7259      1.088     0.7745     0.7972
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109       0.72      0.694       0.75      0.572
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      52/100      10.8G     0.6965     0.7014      1.083     0.7644     0.7658
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.705      0.712       0.75      0.573
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      53/100      10.8G     0.6968     0.7082      1.077     0.7698     0.7725
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.732      0.708      0.756       0.58
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      54/100      10.8G     0.6874      0.674      1.066     0.7561     0.7375
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.722      0.698      0.749      0.572
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      55/100      10.8G     0.6859     0.6863      1.068      0.762     0.7538
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.715      0.703      0.754      0.577
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      56/100      10.8G     0.6778     0.6721      1.065     0.7458     0.7371
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.705      0.696      0.748       0.57
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      57/100      10.8G     0.6685     0.6657       1.06     0.7365     0.7314
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.704      0.701       0.75      0.579
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      58/100      10.8G     0.6701      0.655      1.061     0.7404     0.7203
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.681      0.719       0.74      0.571
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      59/100      10.8G     0.6561     0.6443      1.054     0.7266     0.7059
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.708        0.7      0.741      0.573
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      60/100      10.8G     0.6539     0.6333      1.052     0.7195     0.6959
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.709      0.717      0.757      0.586
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      61/100      10.8G     0.6505     0.6338      1.049     0.7184     0.6934
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.711      0.723      0.743      0.574
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      62/100      10.8G      0.638     0.6206      1.036     0.7024     0.6872
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.733      0.691      0.747      0.573
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      63/100      10.8G     0.6449     0.6097      1.044     0.7123     0.6708
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.744      0.708      0.759      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      64/100      10.8G     0.6386     0.6069      1.037     0.7046      0.673
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109       0.72      0.719      0.755      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      65/100      10.8G     0.6382     0.6044       1.04     0.7052     0.6656
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.716      0.715      0.751       0.58
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      66/100      10.8G     0.6271       0.59      1.026     0.6943     0.6437
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.713      0.727      0.756      0.583
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      67/100      10.8G     0.6198     0.5749      1.025     0.6832     0.6284
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.715      0.721      0.752      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      68/100      10.8G     0.6151      0.567      1.024     0.6799     0.6221
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.744      0.694      0.743      0.577
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      69/100      10.8G     0.6138     0.5651      1.021     0.6757     0.6205
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.731        0.7      0.748      0.579
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      70/100      10.8G     0.6074     0.5594      1.016       0.67     0.6131
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.707       0.73       0.75      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      71/100      10.8G     0.6075     0.5516      1.017     0.6711     0.6058
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.724      0.723      0.753      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      72/100      10.8G     0.5997     0.5464      1.016      0.665     0.6056
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.735      0.713      0.746      0.577
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      73/100      10.8G     0.5946     0.5305      1.008     0.6584     0.5811
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.742      0.691      0.741      0.575
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      74/100      10.8G      0.594     0.5389       1.01     0.6609     0.5938
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109       0.72      0.722      0.748      0.578
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      75/100      10.8G     0.5904     0.5276      1.006     0.6542     0.5766
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.736        0.7      0.748      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      76/100      10.8G     0.5945     0.5282      1.006     0.6594     0.5877
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.736      0.717      0.751      0.584
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      77/100      10.8G     0.5821     0.5182      1.002     0.6439     0.5721
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.746      0.712      0.751      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      78/100      10.8G     0.5802     0.5127      1.001     0.6411     0.5638
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.739       0.71      0.752      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      79/100      10.8G     0.5768     0.5052      1.001     0.6383     0.5515
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.738      0.709      0.756      0.587
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      80/100      10.8G     0.5728     0.4969     0.9989     0.6339      0.542
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.743      0.716      0.756      0.588
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      81/100      10.8G     0.5675     0.4884     0.9934      0.628     0.5363
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.736      0.712      0.751      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      82/100      10.8G     0.5679     0.4946     0.9941      0.629     0.5432
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.762      0.695      0.751      0.583
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      83/100      10.8G     0.5625     0.4779     0.9848     0.6234     0.5282
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.755      0.699      0.752      0.586
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      84/100      10.9G      0.556     0.4766      0.986     0.6121     0.5268
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.739      0.713       0.75      0.584
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      85/100      10.8G     0.5509     0.4662     0.9873     0.6088     0.5086
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.736      0.713      0.747      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      86/100      10.8G     0.5483     0.4676     0.9832     0.6075     0.5159
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.747      0.705      0.744      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      87/100      10.8G     0.5441     0.4601     0.9776     0.5977     0.5088
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.741      0.711      0.744      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      88/100      10.8G      0.546     0.4588     0.9767     0.6049     0.5032
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.753      0.697      0.744      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      89/100      10.8G     0.5357     0.4449     0.9701     0.5918     0.4869
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.738       0.71      0.744       0.58
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      90/100      10.8G       0.53     0.4473     0.9759     0.5874     0.4938
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.749      0.698      0.742      0.578
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# /opt/conda/lib/python3.10/multiprocessing/popen_fork.py:66: RuntimeWarning: os.fork() was called. os.fork() is incompatible with multithreaded code, and JAX is multithreaded, so this will likely lead to a deadlock.
#   self.pid = os.fork()
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      91/100      10.8G     0.4771     0.3324     0.9303     0.5033     0.3172
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.724      0.713      0.738      0.571
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      92/100      10.8G      0.465     0.3143     0.9291     0.4942     0.2987
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.748      0.696      0.742      0.578
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      93/100      10.8G     0.4589     0.3111     0.9224     0.4887     0.2917
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.747      0.698      0.742      0.579
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      94/100      10.8G     0.4537     0.3045     0.9212     0.4825     0.2887
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.738      0.713      0.747      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      95/100      10.8G     0.4524     0.2999     0.9199     0.4787      0.282
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.731      0.726       0.75      0.584
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      96/100      10.8G     0.4484     0.2952      0.914     0.4769     0.2756
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.748      0.705      0.746      0.581
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      97/100      10.8G     0.4428     0.2953     0.9141     0.4695     0.2776
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.749      0.709      0.749      0.585
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      98/100      10.8G     0.4393     0.2859     0.9109     0.4657     0.2649
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.742      0.707      0.747      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      99/100      10.8G     0.4376     0.2883     0.9141     0.4619     0.2673
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.741      0.714      0.749      0.583
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#     100/100      10.8G     0.4373     0.2786     0.9114     0.4625     0.2579
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.722      0.725      0.744       0.58
#
# 100 epochs completed in 8.178 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 64.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 64.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla T4, 15102MiB)
# YOLOv10x summary (fused): 503 layers, 31589858 parameters, 0 gradients, 169.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4109      0.743      0.716      0.756      0.588
#           hand-raising        798       1775       0.81      0.792      0.826      0.622
#                reading        798       1720      0.709      0.694      0.735      0.575
#                writing        798        614       0.71      0.661      0.707      0.567
# Speed: 0.2ms preprocess, 37.3ms inference, 0.0ms loss, 0.2ms postprocess per image
# Results saved to runs/detect/train
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg1 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg2 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:        metrics/mAP50(B) ▁▁▄▄▅▅▆▆▇▇▇▇████████████████████████████
# wandb:     metrics/mAP50-95(B) ▁▂▄▄▅▅▆▆▆▆▇▇▇▇▇▇████████████████████████
# wandb:    metrics/precision(B) ▁▁▃▄▅▄▅▅▅▆▆▆▇▇▇▇▇▇▇▇▇▇▇▇▇▇▇██▇██████████
# wandb:       metrics/recall(B) ▁▂▄▅▅▆▆▆▇▆▇▇▇▇▇▇█▇▇█▇▇▇▇███▇████▇███▇███
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:            train/box_om ▇█▇▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/box_oo ▇█▇▆▆▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/cls_om ██▆▆▆▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/cls_oo █▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/dfl_om ▇█▇▆▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/dfl_oo ▇█▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:              val/box_om █▆▄▃▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/box_oo █▆▄▄▃▃▂▂▂▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/cls_om █▇▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂
# wandb:              val/cls_oo █▇▄▄▃▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂▂▂▂
# wandb:              val/dfl_om █▆▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/dfl_oo █▅▄▃▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 4e-05
# wandb:                  lr/pg1 4e-05
# wandb:                  lr/pg2 4e-05
# wandb:        metrics/mAP50(B) 0.75608
# wandb:     metrics/mAP50-95(B) 0.58778
# wandb:    metrics/precision(B) 0.74286
# wandb:       metrics/recall(B) 0.71586
# wandb:            model/GFLOPs 171.02
# wandb:        model/parameters 31660658
# wandb: model/speed_PyTorch(ms) 39.987
# wandb:            train/box_om 0.43726
# wandb:            train/box_oo 0.46249
# wandb:            train/cls_om 0.2786
# wandb:            train/cls_oo 0.25794
# wandb:            train/dfl_om 0.91137
# wandb:            train/dfl_oo 0.92442
# wandb:              val/box_om 0.80645
# wandb:              val/box_oo 0.84612
# wandb:              val/cls_om 0.99252
# wandb:              val/cls_oo 1.18487
# wandb:              val/dfl_om 1.26635
# wandb:              val/dfl_oo 1.2733
# wandb:
# wandb: 🚀 View run train at: https://wandb.ai/nontaphat/YOLOv8/runs/0dpoqjyq
# wandb: ⭐️ View project at: https://wandb.ai/nontaphat/YOLOv8
# wandb: Synced 5 W&B file(s), 24 media file(s), 5 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240607_112217-0dpoqjyq/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
