# %%
# !python --version
# Out:
# Python 3.10.13

# %%
#git clone yolov10
# !git clone https://github.com/THU-MIG/yolov10.git
# Out:
# Cloning into 'yolov10'...
# remote: Enumerating objects: 20130, done.
# remote: Counting objects: 100% (209/209), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 20130 (delta 140), reused 182 (delta 121), pack-reused 19921
# Receiving objects: 100% (20130/20130), 11.30 MiB | 17.55 MiB/s, done.
# Resolving deltas: 100% (14119/14119), done.

# %%
cd yolov10
# Out:
# /kaggle/working/yolov10

# %%
# !pip install .
# Out:
# Processing /kaggle/working/yolov10
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: matplotlib>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (3.7.5)
# Requirement already satisfied: opencv-python>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.9.0.80)
# Requirement already satisfied: pillow>=7.1.2 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (9.5.0)
# Requirement already satisfied: pyyaml>=5.3.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (6.0.1)
# Requirement already satisfied: requests>=2.23.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.31.0)
# Requirement already satisfied: scipy>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (1.11.4)
# Requirement already satisfied: torch>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.1.2)
# Requirement already satisfied: torchvision>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (0.16.2)
# Requirement already satisfied: tqdm>=4.64.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (4.66.1)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (5.9.3)
# Requirement already satisfied: py-cpuinfo in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (9.0.0)
# Collecting thop>=0.1.1 (from ultralytics==8.1.34)
#   Downloading thop-0.1.1.post2209072238-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: pandas>=1.1.4 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (2.1.4)
# Requirement already satisfied: seaborn>=0.11.0 in /opt/conda/lib/python3.10/site-packages (from ultralytics==8.1.34) (0.12.2)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.4.5)
# Requirement already satisfied: numpy<2,>=1.20 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (21.3)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib>=3.3.0->ultralytics==8.1.34) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.1.4->ultralytics==8.1.34) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests>=2.23.0->ultralytics==8.1.34) (2024.2.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.13.1)
# Requirement already satisfied: typing-extensions in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (4.9.0)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.2.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (3.1.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from torch>=1.8.0->ultralytics==8.1.34) (2024.2.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib>=3.3.0->ultralytics==8.1.34) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.8.0->ultralytics==8.1.34) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.8.0->ultralytics==8.1.34) (1.3.0)
# Downloading thop-0.1.1.post2209072238-py3-none-any.whl (15 kB)
# Building wheels for collected packages: ultralytics
#   Building wheel for ultralytics (pyproject.toml) ... done
#   Created wheel for ultralytics: filename=ultralytics-8.1.34-py3-none-any.whl size=728447 sha256=5ff72caba916f448ae59a30ed217dd856014e3645a91a3fcc3eee078ad5f7cfd
#   Stored in directory: /tmp/pip-ephem-wheel-cache-svj84l62/wheels/42/8a/a9/9cce36b0b3d4ada7292a5a495abef6993ad1db52a921496752
# Successfully built ultralytics
# Installing collected packages: thop, ultralytics
# Successfully installed thop-0.1.1.post2209072238 ultralytics-8.1.34

# %%
import os
import urllib.request

# Create a directory for the weights in the current working directory
weights_dir = os.path.join(os.getcwd(), "weights")
os.makedirs(weights_dir, exist_ok=True)

# URLs of the weight files
urls = [
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10n.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10s.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10m.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10b.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10x.pt",
    "https://github.com/jameslahm/yolov10/releases/download/v1.0/yolov10l.pt"
]

# Download each file
for url in urls:
    file_name = os.path.join(weights_dir, os.path.basename(url))
    urllib.request.urlretrieve(url, file_name)
    print(f"Downloaded {file_name}")
# Out:
# Downloaded /kaggle/working/yolov10/weights/yolov10n.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10s.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10m.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10b.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10x.pt
# Downloaded /kaggle/working/yolov10/weights/yolov10l.pt

# %%
# !pip install wandb --upgrade
# Out:
# Requirement already satisfied: wandb in /opt/conda/lib/python3.10/site-packages (0.16.6)
# Collecting wandb
#   Downloading wandb-0.17.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (10 kB)
# Requirement already satisfied: click!=8.0.0,>=7.1 in /opt/conda/lib/python3.10/site-packages (from wandb) (8.1.7)
# Requirement already satisfied: docker-pycreds>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (0.4.0)
# Requirement already satisfied: gitpython!=3.1.29,>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.1.41)
# Requirement already satisfied: platformdirs in /opt/conda/lib/python3.10/site-packages (from wandb) (4.2.0)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (3.20.3)
# Requirement already satisfied: psutil>=5.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (5.9.3)
# Requirement already satisfied: pyyaml in /opt/conda/lib/python3.10/site-packages (from wandb) (6.0.1)
# Requirement already satisfied: requests<3,>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (2.31.0)
# Requirement already satisfied: sentry-sdk>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from wandb) (1.45.0)
# Requirement already satisfied: setproctitle in /opt/conda/lib/python3.10/site-packages (from wandb) (1.3.3)
# Requirement already satisfied: setuptools in /opt/conda/lib/python3.10/site-packages (from wandb) (69.0.3)
# Requirement already satisfied: six>=1.4.0 in /opt/conda/lib/python3.10/site-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: gitdb<5,>=4.0.1 in /opt/conda/lib/python3.10/site-packages (from gitpython!=3.1.29,>=1.0.0->wandb) (4.0.11)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2.0.0->wandb) (2024.2.2)
# Requirement already satisfied: smmap<6,>=3.0.1 in /opt/conda/lib/python3.10/site-packages (from gitdb<5,>=4.0.1->gitpython!=3.1.29,>=1.0.0->wandb) (5.0.1)
# Downloading wandb-0.17.0-py3-none-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (6.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 62.8 MB/s eta 0:00:0000:0100:01
# Installing collected packages: wandb
#   Attempting uninstall: wandb
#     Found existing installation: wandb 0.16.6
#     Uninstalling wandb-0.16.6:
#       Successfully uninstalled wandb-0.16.6
# Successfully installed wandb-0.17.0

# %%
import wandb
wandb.login()
# Out:
# wandb: Logging into wandb.ai. (Learn how to deploy a W&B server locally: https://wandb.me/wandb-server)
# wandb: You can find your API key in your browser here: https://wandb.ai/authorize
# wandb: Paste an API key from your profile and hit enter, or press ctrl+c to quit:
#   ········································
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
#train model
# !yolo task=detect mode=train epochs=100 batch=8 plots=True model=weights/yolov10x.pt data=/kaggle/input/detecting-student-classroom-behavior2/kaggle_config_fold0.yaml
# Out:
# New https://pypi.org/project/ultralytics/8.2.24 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# engine/trainer: task=detect, mode=train, model=weights/yolov10x.pt, data=/kaggle/input/detecting-student-classroom-behavior2/kaggle_config_fold0.yaml, epochs=100, time=None, patience=100, batch=8, imgsz=640, save=True, save_period=-1, val_period=1, cache=False, device=None, workers=8, project=None, name=train, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=False, opset=None, workspace=4, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, label_smoothing=0.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train
# Downloading https://ultralytics.com/assets/Arial.ttf to '/root/.config/Ultralytics/Arial.ttf'...
# 100%|████████████████████████████████████████| 755k/755k [00:00<00:00, 23.7MB/s]
# 2024-05-29 05:38:00.663109: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-05-29 05:38:00.663220: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-05-29 05:38:00.793514: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=3
#
#                    from  n    params  module                                       arguments
#   0                  -1  1      2320  ultralytics.nn.modules.conv.Conv             [3, 80, 3, 2]
#   1                  -1  1    115520  ultralytics.nn.modules.conv.Conv             [80, 160, 3, 2]
#   2                  -1  3    436800  ultralytics.nn.modules.block.C2f             [160, 160, 3, True]
#   3                  -1  1    461440  ultralytics.nn.modules.conv.Conv             [160, 320, 3, 2]
#   4                  -1  6   3281920  ultralytics.nn.modules.block.C2f             [320, 320, 6, True]
#   5                  -1  1    213120  ultralytics.nn.modules.block.SCDown          [320, 640, 3, 2]
#   6                  -1  6   4604160  ultralytics.nn.modules.block.C2fCIB          [640, 640, 6, True]
#   7                  -1  1    417920  ultralytics.nn.modules.block.SCDown          [640, 640, 3, 2]
#   8                  -1  3   2712960  ultralytics.nn.modules.block.C2fCIB          [640, 640, 3, True]
#   9                  -1  1   1025920  ultralytics.nn.modules.block.SPPF            [640, 640, 5]
#  10                  -1  1   1545920  ultralytics.nn.modules.block.PSA             [640, 640]
#  11                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  12             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  13                  -1  3   3122560  ultralytics.nn.modules.block.C2fCIB          [1280, 640, 3, True]
#  14                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  15             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  16                  -1  3   1948800  ultralytics.nn.modules.block.C2f             [960, 320, 3]
#  17                  -1  1    922240  ultralytics.nn.modules.conv.Conv             [320, 320, 3, 2]
#  18            [-1, 13]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  19                  -1  3   2917760  ultralytics.nn.modules.block.C2fCIB          [960, 640, 3, True]
#  20                  -1  1    417920  ultralytics.nn.modules.block.SCDown          [640, 640, 3, 2]
#  21            [-1, 10]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  22                  -1  3   3122560  ultralytics.nn.modules.block.C2fCIB          [1280, 640, 3, True]
#  23        [16, 19, 22]  1   4390818  ultralytics.nn.modules.head.v10Detect        [3, [320, 640, 640]]
# YOLOv10x summary: 688 layers, 31660658 parameters, 31660642 gradients, 171.0 GFLOPs
#
# Transferred 1123/1135 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train', view at http://localhost:6006/
# wandb: Currently logged in as: nontaphatfirm (nontaphat). Use `wandb login --relogin` to force relogin
# wandb: Tracking run with wandb version 0.17.0
# wandb: Run data is saved locally in /kaggle/working/yolov10/wandb/run-20240529_053812-h6bntwmi
# wandb: Run `wandb offline` to turn off syncing.
# wandb: Syncing run train
# wandb: ⭐️ View project at https://wandb.ai/nontaphat/YOLOv8
# wandb: 🚀 View run at https://wandb.ai/nontaphat/YOLOv8/runs/h6bntwmi
# Freezing layer 'model.23.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks with YOLOv8n...
# Downloading https://github.com/ultralytics/assets/releases/download/v8.1.0/yolov8n.pt to 'yolov8n.pt'...
# 100%|███████████████████████████████████████| 6.23M/6.23M [00:00<00:00, 106MB/s]
# AMP: checks passed ✅
# train: Scanning /kaggle/input/detecting-student-classroom-behavior2/data_test2/d
# train: WARNING ⚠️ /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/images/train_fold_0/1276033.jpg: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.1459]
# train: WARNING ⚠️ Cache directory /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/labels is not writeable, cache not saved.
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
# val: Scanning /kaggle/input/detecting-student-classroom-behavior2/data_test2/dat
# val: WARNING ⚠️ Cache directory /kaggle/input/detecting-student-classroom-behavior2/data_test2/data_test2/labels is not writeable, cache not saved.
# Plotting labels to runs/detect/train/labels.jpg...
# optimizer: 'optimizer=auto' found, ignoring 'lr0=0.01' and 'momentum=0.937' and determining best 'optimizer', 'lr0' and 'momentum' automatically...
# optimizer: AdamW(lr=0.001429, momentum=0.9) with parameter groups 185 weight(decay=0.0), 198 weight(decay=0.0005), 197 bias(decay=0.0)
# TensorBoard: WARNING ⚠️ TensorBoard graph visualization failure
# Image sizes 640 train, 640 val
# Using 4 dataloader workers
# Logging results to runs/detect/train
# Starting training for 100 epochs...
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       1/100      10.6G      1.311      1.971      1.506      1.339      2.281
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.233      0.347      0.195     0.0895
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       2/100      10.9G      1.487      1.981      1.656      1.552       2.16
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.295      0.437      0.294      0.164
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       3/100      10.9G      1.416      1.875      1.601      1.482      2.043
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.349      0.494      0.334       0.19
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       4/100      10.8G      1.352      1.774      1.551      1.421      1.942
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.431      0.496       0.39      0.237
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       5/100      10.8G      1.282      1.665      1.501      1.359      1.828
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.451      0.508      0.447      0.279
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       6/100      10.9G      1.217      1.566       1.45      1.296      1.707
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.449      0.572      0.445      0.286
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       7/100      10.8G      1.179       1.53      1.431      1.264      1.654
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.49      0.579      0.522      0.345
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       8/100      10.8G      1.135      1.479      1.405      1.214      1.609
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.481      0.583      0.502      0.339
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#       9/100      10.9G      1.104       1.45      1.383      1.194       1.59
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.484      0.582      0.525      0.362
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      10/100      10.8G      1.085       1.37      1.351      1.167      1.499
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.488       0.63      0.564      0.393
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      11/100      10.8G      1.058      1.336      1.342      1.142      1.456
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.521      0.598       0.55      0.385
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      12/100      10.8G      1.036      1.328      1.332      1.121      1.443
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.547      0.618      0.573        0.4
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      13/100      10.8G      1.019      1.288      1.316      1.102      1.402
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.553      0.623      0.594      0.415
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      14/100      10.9G      1.001      1.251      1.301      1.086      1.372
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.581      0.623      0.615      0.439
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      15/100      10.9G     0.9894      1.232      1.297       1.07       1.35
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.584      0.636      0.606      0.431
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      16/100      10.9G     0.9718      1.215      1.281      1.058      1.325
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.589      0.654      0.652      0.475
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      17/100      10.8G     0.9538      1.167      1.268      1.033      1.274
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.622      0.641      0.667      0.485
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      18/100      10.8G     0.9538      1.178      1.268      1.032      1.286
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.605      0.609      0.615      0.441
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      19/100      10.8G     0.9357      1.141       1.25      1.015      1.246
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.592      0.649      0.653      0.481
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      20/100      10.8G     0.9232      1.129      1.244      1.006      1.229
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.644       0.64      0.673      0.496
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      21/100      10.8G     0.8966       1.08      1.222     0.9823      1.194
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.617      0.658       0.68      0.505
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      22/100      10.8G     0.8834      1.075      1.218     0.9647      1.185
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.629      0.658       0.68      0.496
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      23/100      10.8G     0.8931      1.062      1.221     0.9767      1.162
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.654      0.684      0.714      0.526
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      24/100      10.8G     0.8751      1.036      1.208     0.9602      1.139
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.638      0.683      0.699      0.519
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      25/100      10.8G     0.8631      1.006      1.204     0.9452        1.1
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.652       0.67      0.707      0.521
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      26/100      10.9G     0.8642     0.9881      1.198     0.9511      1.079
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.644      0.684      0.711      0.525
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      27/100      10.8G     0.8563      1.014      1.198      0.941      1.105
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.628      0.692      0.703      0.519
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      28/100      10.9G     0.8487     0.9927      1.188     0.9268      1.081
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.664       0.69      0.721      0.535
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      29/100      10.8G     0.8341     0.9634      1.181     0.9176      1.061
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.663      0.687      0.724      0.542
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      30/100      10.8G     0.8327     0.9527      1.177     0.9108      1.049
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.689      0.683       0.73      0.549
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      31/100      10.8G     0.8171     0.9219      1.166     0.8936      1.022
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.655      0.689      0.716      0.538
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      32/100      10.8G     0.8162     0.9408       1.17     0.8923      1.036
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.665       0.71      0.734      0.553
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      33/100      10.8G     0.8152     0.9222      1.166     0.8929      1.016
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.699      0.687      0.741      0.559
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      34/100      10.9G     0.8087     0.8964      1.158     0.8883      0.982
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.686      0.682      0.729      0.551
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      35/100      10.8G     0.7884     0.8808      1.146     0.8617     0.9626
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.679      0.712      0.746      0.567
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      36/100      10.8G     0.7878     0.8736      1.149     0.8603     0.9583
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.707      0.692      0.745      0.559
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      37/100      10.8G     0.7789     0.8625      1.133     0.8523     0.9479
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.698      0.704      0.746      0.567
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      38/100      10.8G      0.774     0.8472      1.144     0.8487     0.9299
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.711      0.706      0.755      0.577
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      39/100      10.9G     0.7683     0.8394      1.132      0.845     0.9145
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.709      0.688      0.745      0.564
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      40/100      10.9G     0.7542     0.8189      1.124     0.8256     0.9011
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.679      0.713       0.75      0.572
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      41/100      10.9G     0.7509      0.816      1.119     0.8238      0.892
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231        0.7      0.711      0.751      0.575
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      42/100      10.8G     0.7474     0.7926      1.116     0.8278     0.8723
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.709      0.704      0.755      0.573
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      43/100      10.9G     0.7409     0.7923      1.116     0.8125     0.8723
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.72      0.708      0.761      0.584
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      44/100      10.8G     0.7336     0.7929      1.112     0.8039     0.8669
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.683      0.732      0.761      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      45/100      10.8G     0.7238     0.7711      1.099     0.7996     0.8483
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.714      0.715      0.767      0.586
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      46/100      10.8G     0.7218     0.7517      1.096     0.7955     0.8276
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.699      0.715      0.763      0.587
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      47/100      10.8G     0.7138     0.7512      1.089      0.788     0.8279
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.708      0.718      0.767       0.59
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      48/100      10.9G     0.7085     0.7332      1.092     0.7801     0.8086
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.701      0.713      0.758      0.582
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      49/100      10.9G     0.7055     0.7121      1.086     0.7774     0.7813
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231        0.7      0.722      0.765      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      50/100      10.8G     0.7048     0.7207      1.088      0.778     0.7893
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.701      0.731      0.762      0.587
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      51/100      10.9G     0.6941     0.7145      1.082     0.7686      0.786
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.698      0.717      0.759      0.587
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      52/100      10.8G      0.688     0.6923      1.072     0.7622     0.7597
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.703      0.722      0.763      0.589
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      53/100      10.8G     0.6915     0.6957      1.073     0.7604     0.7674
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.714       0.72      0.762      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      54/100      10.8G     0.6865     0.6879      1.071     0.7552     0.7565
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.735      0.704      0.771      0.595
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      55/100      10.8G     0.6818     0.6743      1.067      0.749     0.7409
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.719      0.719      0.768      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      56/100      10.8G     0.6701     0.6609      1.056      0.738     0.7237
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.725      0.699      0.754      0.579
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      57/100      10.8G     0.6601     0.6539      1.054     0.7278      0.718
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.721      0.726       0.76      0.588
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      58/100      10.9G     0.6647     0.6563      1.056     0.7343     0.7219
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.729      0.712      0.765      0.589
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      59/100      10.8G     0.6573     0.6355      1.052     0.7249     0.6929
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.75      0.691      0.764      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      60/100      10.8G     0.6587     0.6357      1.055     0.7258     0.6942
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.708      0.734      0.764      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      61/100      10.8G     0.6401     0.6275      1.042     0.7067     0.6866
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.721      0.713      0.763      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      62/100      10.9G     0.6469     0.6167      1.046     0.7153     0.6806
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.74      0.706       0.77      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      63/100      10.8G     0.6435     0.6122      1.043     0.7114     0.6723
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.722      0.724      0.769      0.599
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      64/100      10.8G     0.6348     0.6054       1.04     0.7029     0.6685
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.736       0.72       0.77      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      65/100      10.9G     0.6383     0.6143      1.041     0.7049     0.6809
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.722      0.731      0.772      0.597
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      66/100      10.8G     0.6289      0.584       1.03      0.697     0.6432
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.721      0.718      0.769      0.598
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      67/100      10.8G     0.6202      0.577       1.03     0.6879     0.6312
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.724      0.721      0.771      0.598
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      68/100      10.8G     0.6184      0.562      1.029     0.6808     0.6141
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.723      0.731      0.768      0.594
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      69/100      10.9G     0.6121      0.562      1.021     0.6737     0.6189
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.727      0.716      0.769      0.598
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      70/100      10.9G      0.603      0.544      1.017     0.6686     0.6033
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.74      0.715       0.77      0.602
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      71/100      10.8G      0.607     0.5508      1.022     0.6718     0.6053
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.74      0.707      0.766      0.597
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      72/100      10.8G     0.5986     0.5384      1.013     0.6646     0.5872
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.737      0.708      0.766      0.595
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      73/100      10.9G     0.5897     0.5241      1.007     0.6546     0.5749
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.742      0.716      0.768      0.599
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      74/100      10.8G     0.5923     0.5349       1.01     0.6551     0.5946
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.732      0.722       0.76      0.592
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      75/100      10.8G     0.5866     0.5205      1.003     0.6493     0.5733
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.736      0.712      0.767      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      76/100      10.9G     0.5875     0.5208      1.009     0.6514     0.5786
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.729      0.731      0.767      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      77/100      10.9G     0.5813     0.5173      1.003     0.6464     0.5719
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.726      0.726      0.766      0.595
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      78/100      10.8G     0.5741     0.5093      0.996     0.6387     0.5614
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.752      0.706      0.762      0.595
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      79/100      10.8G     0.5735     0.5132      1.001     0.6336     0.5629
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.742      0.711       0.76      0.594
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      80/100      10.9G     0.5648     0.5005     0.9972     0.6261     0.5508
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.75      0.708      0.764      0.598
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      81/100      10.8G     0.5607     0.4878     0.9909     0.6226     0.5386
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.728      0.725      0.764      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      82/100      10.8G     0.5587      0.488     0.9904     0.6191      0.538
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.741       0.71      0.765      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      83/100      10.8G     0.5492     0.4821     0.9893     0.6088     0.5277
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.743      0.722      0.764      0.597
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      84/100      10.8G     0.5564     0.4748     0.9916     0.6165     0.5257
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.732      0.712      0.757      0.591
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      85/100      10.8G     0.5502      0.467     0.9879     0.6081     0.5111
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.746      0.711      0.761      0.595
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      86/100      10.8G     0.5476     0.4627     0.9867     0.6095     0.5062
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.74      0.712      0.759      0.594
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      87/100      10.8G     0.5463     0.4592     0.9838     0.6052      0.506
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.737      0.713       0.76      0.591
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      88/100      10.9G     0.5451     0.4502     0.9735     0.6049     0.4964
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.745      0.707      0.759      0.591
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      89/100      10.9G     0.5334       0.45     0.9798     0.5925     0.4969
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.76      0.708       0.76      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      90/100      10.9G     0.5363     0.4504     0.9803     0.5951      0.497
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.755      0.709      0.758      0.592
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01), CLAHE(p=0.01, clip_limit=(1, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      91/100      10.8G     0.4699     0.3303     0.9371     0.4976     0.3174
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.735      0.718      0.759      0.589
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      92/100      10.9G     0.4645     0.3154     0.9284     0.4932     0.3032
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.725       0.73      0.762      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      93/100      10.8G      0.458     0.3091     0.9266     0.4853     0.2935
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.744       0.71      0.764      0.594
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      94/100      10.8G     0.4583     0.3095     0.9232     0.4865     0.2946
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.734      0.717       0.76      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      95/100      10.8G     0.4543     0.3014     0.9214     0.4832     0.2904
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.736      0.716       0.76      0.593
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      96/100      10.8G      0.445     0.2946      0.919       0.47     0.2825
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.746      0.724      0.764      0.597
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      97/100      10.8G     0.4385     0.2877     0.9134     0.4654      0.269
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.753      0.705      0.762      0.594
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      98/100      10.8G     0.4391       0.29     0.9146     0.4634     0.2782
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.752      0.708      0.763      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#      99/100      10.9G     0.4325     0.2827     0.9098     0.4571     0.2638
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.757      0.712      0.763      0.596
#
#       Epoch    GPU_mem     box_om     cls_om     dfl_om     box_oo     cls_oo     dfl_oo  Instances       Size
#     100/100      10.8G     0.4314     0.2769     0.9081     0.4543     0.2579
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231      0.748       0.71      0.761      0.594
#
# 100 epochs completed in 9.700 hours.
# Optimizer stripped from runs/detect/train/weights/last.pt, 64.1MB
# Optimizer stripped from runs/detect/train/weights/best.pt, 64.1MB
#
# Validating runs/detect/train/weights/best.pt...
# Ultralytics YOLOv8.1.34 🚀 Python-3.10.13 torch-2.1.2 CUDA:0 (Tesla P100-PCIE-16GB, 16276MiB)
# YOLOv10x summary (fused): 503 layers, 31589858 parameters, 0 gradients, 169.8 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  m
#                    all        798       4231       0.74      0.717       0.77      0.602
#           hand-raising        798       1744      0.832       0.76      0.835      0.625
#                reading        798       1818      0.696      0.736      0.758      0.594
#                writing        798        669      0.692      0.653      0.716      0.586
# Speed: 0.1ms preprocess, 19.1ms inference, 0.0ms loss, 0.1ms postprocess per image
# Results saved to runs/detect/train
# wandb:
# wandb:
# wandb: Run history:
# wandb:                  lr/pg0 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg1 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:                  lr/pg2 ▃███▇▇▇▇▇▇▆▆▆▆▆▅▅▅▅▅▅▄▄▄▄▄▃▃▃▃▃▃▂▂▂▂▂▁▁▁
# wandb:        metrics/mAP50(B) ▁▃▄▅▅▆▇▆▇▇▇▇▇▇██████████████████████████
# wandb:     metrics/mAP50-95(B) ▁▂▄▄▅▅▆▆▇▇▇▇▇▇▇▇████████████████████████
# wandb:    metrics/precision(B) ▁▃▄▄▅▅▆▆▆▇▆▇▇▇▇▇▇▇▇▇▇███▇███████████████
# wandb:       metrics/recall(B) ▁▄▅▅▆▆▇▆▇▇▇▇▇▇▇▇█████▇▇▇████████████████
# wandb:            model/GFLOPs ▁
# wandb:        model/parameters ▁
# wandb: model/speed_PyTorch(ms) ▁
# wandb:            train/box_om ▇█▇▆▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/box_oo ▇█▇▆▆▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/cls_om ██▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/cls_oo █▇▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/dfl_om ▇█▆▆▅▅▅▅▄▄▄▄▄▄▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:            train/dfl_oo ▇█▇▆▆▅▅▅▄▄▄▄▄▄▄▄▃▃▃▃▃▃▃▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁
# wandb:              val/box_om █▅▃▃▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/box_oo █▅▄▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/cls_om █▅▄▃▃▂▂▂▂▁▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂
# wandb:              val/cls_oo █▆▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▂▂▂▂▂▂▂
# wandb:              val/dfl_om █▄▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:              val/dfl_oo █▄▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁
# wandb:
# wandb: Run summary:
# wandb:                  lr/pg0 4e-05
# wandb:                  lr/pg1 4e-05
# wandb:                  lr/pg2 4e-05
# wandb:        metrics/mAP50(B) 0.76963
# wandb:     metrics/mAP50-95(B) 0.60163
# wandb:    metrics/precision(B) 0.73983
# wandb:       metrics/recall(B) 0.71663
# wandb:            model/GFLOPs 171.02
# wandb:        model/parameters 31660658
# wandb: model/speed_PyTorch(ms) 20.152
# wandb:            train/box_om 0.43139
# wandb:            train/box_oo 0.45432
# wandb:            train/cls_om 0.2769
# wandb:            train/cls_oo 0.25794
# wandb:            train/dfl_om 0.90808
# wandb:            train/dfl_oo 0.91973
# wandb:              val/box_om 0.8194
# wandb:              val/box_oo 0.8553
# wandb:              val/cls_om 0.98711
# wandb:              val/cls_oo 1.15453
# wandb:              val/dfl_om 1.2579
# wandb:              val/dfl_oo 1.26409
# wandb:
# wandb: 🚀 View run train at: https://wandb.ai/nontaphat/YOLOv8/runs/h6bntwmi
# wandb: ⭐️ View project at: https://wandb.ai/nontaphat/YOLOv8
# wandb: Synced 5 W&B file(s), 24 media file(s), 5 artifact file(s) and 0 other file(s)
# wandb: Find logs at: ./wandb/run-20240529_053812-h6bntwmi/logs
# 💡 Learn more at https://docs.ultralytics.com/modes/train
